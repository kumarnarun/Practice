# %%
                                             ## welocoming the new employee

# %%
Name = input('Enter your name: ')
Gender = input('Enter your gender: ')
Age = input('Enter your age: ')
Age = int(Age)
Experience = input('Enter the years of experience: ')
Experience = int(Experience)
# Out:
# Enter your name: amutha
# Enter your gender: female
# Enter your age: 60
# Enter the years of experience: 40

# %%
if Gender == 'male' and Experience < 5:
    print('''Welcome sir!
    
    Thank you for joining as
           Trainee Role''')
elif Gender == 'male' and 5 >= Experience <= 10:
    print('''Welcome sir!
    
    Thank you for joining as
           Team Lead Role''')
elif Gender == 'male' and Experience > 10:
    print('''Welcome sir!
    
    Thank you for joining in the
           Manager Role''')
elif Gender == 'female' and Experience < 5:
    print('''Welcome mam!
    
    Thank you for joining as
           Trainee Role''')
elif Gender == 'female' and 5 >= Experience <= 10:
    print('''Welcome mam!
    
    Thank you for joining as
           Team Lead Role''')
else:
    print('''Welcome mam!
    
    Thank you for joining in the
           Manager Role''')
# Out:
# Welcome mam!
#
#     Thank you for joining in the
#            Manager Role
