# %%
                               ## Hiring the candidates

# %%
skills = input('Enter your skill sets: ')
# Out:
# Enter your skill sets: python,open CV

# %%
if skills == 'python,pandas,numpy,matplotlib,feature engineering':
    print('your skill set is suitable for data analyst, python developer')
    
elif skills == 'python,pandas,numpy,matplotlib,feature engineering,regression,classification':
    print('your skill set is suitable for data analyst, python developer, Data scientist, machine learning engineer')
    
elif skills == 'python,pandas,regression,classification':
    print('your skill set is suitable for machine learning engineer,python developer')
          
elif skills == 'python,open CV':
    print('your skill set is suitable for deep learning engineer,python developer')
          
elif skills == 'python':
    print('your skill set is suitable for python developer')
          
elif skills == 'python,NLP':
    print('your skill set is suitable for python developer, NLP Engineer')
                
else:
    print('your skill set is not suitable for recommended job')
# Out:
# your skill set is suitable for deep learning engineer,python developer
